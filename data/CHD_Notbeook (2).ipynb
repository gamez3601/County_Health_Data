# %%
import pandas as pd

# %% [markdown]
# ######pandas helps us work with tables of data
#
# ######this establishes the name "panda" as "pd"

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ######this connects your google drive so you can access files

# %%
df=pd.read_csv('/content/gdrive/My Drive/Data/CountyHealthData_2014-2015.csv')

# %% [markdown]
# ######this loads your dataset inot a variable known as "df". Data is ready for analysis

# %%
df
# Out:
#      State Region  Division                      County   FIPS  GEOID  \
# 0       AK   West   Pacific  Aleutians West Census Area   2016   2016
# 1       AK   West   Pacific  Aleutians West Census Area   2016   2016
# 2       AK   West   Pacific           Anchorage Borough   2020   2020
# 3       AK   West   Pacific           Anchorage Borough   2020   2020
# 4       AK   West   Pacific          Bethel Census Area   2050   2050
# ...    ...    ...       ...                         ...    ...    ...
# 6104    WY   West  Mountain                Uinta County  56041  56041
# 6105    WY   West  Mountain             Washakie County  56043  56043
# 6106    WY   West  Mountain             Washakie County  56043  56043
# 6107    WY   West  Mountain               Weston County  56045  56045
# 6108    WY   West  Mountain               Weston County  56045  56045
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# ...

# %% [markdown]
# ######this is your raw data

# %%
df.size
# Out:
# 390976

# %% [markdown]
# ######this represents your total number of data frames

# %%
df.shape
# Out:
# (6109, 64)

# %% [markdown]
# ######this gives you the dimensions in rows and columns

# %%
df.head()
# Out:
#   State Region Division                      County  FIPS  GEOID   SMS Region  \
# 0    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 1    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 2    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 3    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 4    AK   West  Pacific          Bethel Census Area  2050   2050  Insuff Data
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 0  1/1/2014              NaN                0.122  ...                    NaN
# 1  1/1/2015              NaN                0.122  ...                    NaN
# 2  1/1/2014           6827.0                0.125  ...                  15.37
# 3  1/1/2015           6856.0                0.125  ...                  17.08
# 4  1/1/2014          13345.0                0.211  ...                    NaN
#
# ...

# %% [markdown]
# ######this gives you the first few rows of all the data

# %%
df.tail()
# Out:
#      State Region  Division           County   FIPS  GEOID   SMS Region  \
# 6104    WY   West  Mountain     Uinta County  56041  56041  Insuff Data
# 6105    WY   West  Mountain  Washakie County  56043  56043  Insuff Data
# 6106    WY   West  Mountain  Washakie County  56043  56043  Insuff Data
# 6107    WY   West  Mountain    Weston County  56045  56045  Insuff Data
# 6108    WY   West  Mountain    Weston County  56045  56045  Insuff Data
#
#           Year  Premature death  Poor or fair health  ...  \
# 6104  1/1/2015           7436.0                0.135  ...
# 6105  1/1/2014           6580.0                0.106  ...
# 6106  1/1/2015           7572.0                0.106  ...
# 6107  1/1/2014           5633.0                0.162  ...
# 6108  1/1/2015           7819.0                0.162  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 6104                  18.66             0.192               0.090
# ...

# %% [markdown]
# ######this gives you the last few rows of all the data

# %%
df.sample(n=5)
# Out:
#      State   Region            Division           County   FIPS  GEOID  \
# 6043    WV    South      South Atlantic    Taylor County  54091  54091
# 515     CO     West            Mountain   El Paso County   8041   8041
# 1098    IA  Midwest  West North Central    Butler County  19023  19023
# 640     FL    South      South Atlantic    DeSoto County  12027  12027
# 3522    ND  Midwest  West North Central  Stutsman County  38093  38093
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 6043    Region 27  1/1/2014           8896.0                0.268  ...
# 515     Region 21  1/1/2015           6169.0                0.120  ...
# 1098  Insuff Data  1/1/2014           5981.0                0.075  ...
# 640     Region 15  1/1/2014           7540.0                0.162  ...
# 3522  Insuff Data  1/1/2015           6783.0                0.119  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# ...

# %% [markdown]
# ######this gives you 5 random rows from the data

# %%
df["State"]
# Out:
# 0       AK
# 1       AK
# 2       AK
# 3       AK
# 4       AK
#         ..
# 6104    WY
# 6105    WY
# 6106    WY
# 6107    WY
# 6108    WY
# Name: State, Length: 6109, dtype: object

# %% [markdown]
# ######this gives you data for the specific column known as "State"

# %%
df[df["State"] == "NC"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# ######this creates a new dataframe with rows only in the state north carolina
#
# ######This is computed as "NC"

# %%
df = pd.read_csv('/content/gdrive/My Drive/Data/CountyHealthData_2014-2015.csv')

# %% [markdown]
# ######this reloads the original dataframe from the csv

# %%
nc_subset = df[df["State"] == "NC"].copy()

# %% [markdown]
# ######this creates a new dataframe called nc_subset

# %%
df[df["State"] == "NC"].copy
# Out:
# <bound method NDFrame.copy of      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# ######This creates a full copy of that filtered DataFrame
#
# ######This is important if you want to modify it later without changing the original

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
# ...

# %% [markdown]
# ######this displays all the columns in the original data

# %%
nc_subset[['County', 'Year', 'Health care costs']]
# Out:
#                 County      Year  Health care costs
# 3243   Alamance County  1/1/2014             8640.0
# 3244   Alamance County  1/1/2015             9050.0
# 3245  Alexander County  1/1/2014             9316.0
# 3246  Alexander County  1/1/2015             9242.0
# 3247  Alleghany County  1/1/2014             9585.0
# ...                ...       ...                ...
# 3438     Wilson County  1/1/2015             9450.0
# 3439     Yadkin County  1/1/2014            10084.0
# 3440     Yadkin County  1/1/2015            10998.0
# 3441     Yancey County  1/1/2014             7707.0
# 3442     Yancey County  1/1/2015             7870.0
#
# [200 rows x 3 columns]

# %% [markdown]
# ######this line is selecting the columns "County", "Year", and "Health care costs" from the nc_subset dataframe

# %%
print(nc_subset[['County', 'Year', 'Health care costs']])
# Out:
#                 County      Year  Health care costs
# 3243   Alamance County  1/1/2014             8640.0
# 3244   Alamance County  1/1/2015             9050.0
# 3245  Alexander County  1/1/2014             9316.0
# 3246  Alexander County  1/1/2015             9242.0
# 3247  Alleghany County  1/1/2014             9585.0
# ...                ...       ...                ...
# 3438     Wilson County  1/1/2015             9450.0
# 3439     Yadkin County  1/1/2014            10084.0
# 3440     Yadkin County  1/1/2015            10998.0
# 3441     Yancey County  1/1/2014             7707.0
# 3442     Yancey County  1/1/2015             7870.0
#
# [200 rows x 3 columns]

# %% [markdown]
# ######this will display the first and last 5 rows of the nc_subset DataFrame in your output

# %%
nc_subset.to_csv('nc_subset.csv')

# %% [markdown]
# ######this will download the newly created subset into a csv file
